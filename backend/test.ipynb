# %%
import asyncio
import nest_asyncio

from engine.src_platform import QuestionPro

nest_asyncio.apply()

survey_id="12688491"
survey_id_2 = "12032803"

questionpro = QuestionPro(survey_id="12032803", api_key="61d15ae9-8995-4f6b-88ac-3a66e752a3cc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 11
#       8 survey_id="12688491"
#       9 survey_id_2 = "12032803"
# ---> 11 questionpro = QuestionPro(survey_id="12032803", api_key="61d15ae9-8995-4f6b-88ac-3a66e752a3cc")
#
# File c:\Users\hoang\OneDrive\Desktop\cpara\backend\engine\src_platform\questionpro\main.py:60, in QuestionPro.__init__(self, survey_id, api_key)
#      58 self.headers = {'api-key': self.api_key}
#      59 self.response = self._get_response()
# ---> 60 self.data = self._get_data()
#
# File c:\Users\hoang\OneDrive\Desktop\cpara\backend\engine\src_platform\questionpro\main.py:168, in QuestionPro._get_data(self)
#     164 for answer in response_answer['answerValues']:
#     165     answer_values = answer['value']
# --> 168     root_answer = find_answer(answer['answerID'], answer_list)
#     169     if root_answer != None:
# ...

# %%
response = questionpro.response
data = questionpro._get_data()

# %%
data['questions']
# Out:
# [{'id': '144286541',
#   'code': 'Q6_1',
#   'text': 'Test Matrix TEXT_MTRow1',
#   'order': 6.1,
#   'type': 'text_matrix',
#   'answers': ['768621559', '768621560']},
#  {'id': '144286542',
#   'code': 'Q6_2',
#   'text': 'Test Matrix TEXT_MTRow2',
#   'order': 6.2,
#   'type': 'text_matrix',
#   'answers': ['768621561', '768621562']},
#  {'id': '144283383',
#   'code': 'Q5_1',
#   'text': 'Test MA Matrix_MAMA-Row1',
#   'order': 5.1,
#   'type': 'ma_matrix',
#   'answers': ['768601503', '768601504']},
#  {'id': '144283384',
#   'code': 'Q5_2',
#   'text': 'Test MA Matrix_MAMA-Row2',
#   'order': 5.2,
#   'type': 'ma_matrix',
#   'answers': ['768601505', '768601506']},
#  {'id': '144283380',
#   'code': 'Q4_1',
#   'text': 'Test SA Matrix_SAMA-Row1',
#   'order': 4.1,
#   'type': 'sa',
#   'answers': ['768601495', '768601496']},
#  {'id': '144283381',
#   'code': 'Q4_2',
#   'text': 'Test SA Matrix_SAMA-Row2',
#   'order': 4.2,
#   'type': 'sa',
# ...

# %%
data['answers']
# Out:
# [{'id': '768621559',
#   'scale': 1,
#   'text': 'MTCol1',
#   'question': '144286541',
#   'responses': ['151680120', '151680106']},
#  {'id': '768621560',
#   'scale': 2,
#   'text': 'MTCol2',
#   'question': '144286541',
#   'responses': ['151680120', '151680106']},
#  {'id': '768621561',
#   'scale': 1,
#   'text': 'MTCol1',
#   'question': '144286542',
#   'responses': ['151680120', '151680106']},
#  {'id': '768621562',
#   'scale': 2,
#   'text': 'MTCol2',
#   'question': '144286542',
#   'responses': ['151680120', '151680106']},
#  {'id': '768601503',
#   'scale': 1,
#   'text': 'MAMA-Col1',
#   'question': '144283383',
#   'responses': ['151680120', '151680106']},
#  {'id': '768601504',
#   'scale': 2,
#   'text': 'MAMA-Col2',
#   'question': '144283383',
#   'responses': ['151680120', '151680106']},
#  {'id': '768601505',
#   'scale': 1,
#   'text': 'MAMA-Col1',
#   'question': '144283384',
#   'responses': ['151680120']},
#  {'id': '768601506',
#   'scale': 2,
# ...
